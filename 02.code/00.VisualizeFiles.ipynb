# %%
# %pylab inline

import pandas as pd
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
results = pd.read_csv('../04.results/submissionconvolutional_03.csv')

# %%
sample = results.ix[:,1:]
sample.head()
# Out:
#    Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  Class3.2  \
# 0  0.763428  0.167709  0.057008  0.003734  0.176080  0.010366  0.128456
# 1  0.712313  0.333976  0.028679  0.003887  0.355369  0.021074  0.315577
# 2  0.619866  0.479126  0.036154  0.284181  0.194137  0.044710  0.128180
# 3  0.015531  0.998048  0.001374  0.011913  0.982848  0.451999  0.541648
# 4  0.520895  0.470649  0.018086  0.058924  0.390455  0.033233  0.386782
#
#    Class4.1  Class4.2  Class5.1    ...      Class9.3  Class10.1  Class10.2  \
# 0  0.008101  0.155348  0.002709    ...      0.000187   0.005262   0.004260
# 1  0.054812  0.273625  0.004433    ...      0.000636   0.028921   0.009670
# 2  0.049403  0.117664  0.034493    ...      0.054468   0.024422   0.009331
# 3  0.816929  0.103076  0.005560    ...      0.001255   0.342669   0.322725
# 4  0.139091  0.250242  0.016308    ...      0.026511   0.089739   0.058950
#
#    Class10.3  Class11.1  Class11.2  Class11.3  Class11.4  Class11.5  Class11.6
# ...

# %%
d = sample.apply(lambda x : (x**2).sum(),axis=1)
