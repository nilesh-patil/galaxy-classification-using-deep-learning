# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
run = 'densenet_fast_02_32x32'
device_use = '/cpu:0'

# %% [markdown]
# ##### 00. Load Packages

# %%
# %pylab inline


import seaborn as sns
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import tensorflow as tf
import keras

import glob as glob
import cv2 as cv2
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
from keras import backend as K
from keras.models import Sequential, load_model, Model
from keras.layers import Input, Dropout, Activation
from keras.layers import Lambda, Conv2D, MaxPooling2D, Dense

from keras.layers.normalization import BatchNormalization

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/cpu:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16841532729235940659]

# %%
train_files = glob.glob('../01.data/extracted/images_training_rev1/*.jpg')
test_files = glob.glob('../01.data/extracted/images_test_rev1/*.jpg')

# %% [markdown]
# ##### 00. Define functions

# %%
def get_image(image_path,size):
    
    x = cv2.imread(image_path)
    x = cv2.resize(x,size,cv2.INTER_NEAREST)
    return(x)

def get_labels(image_path):
    
    image_id = image_path.split('/')[-1]
    image_number = image_id.split('.')[0]
    values = train_output.loc[np.int(image_number)].values
    
    return(values)

# %%
y_path = '../01.data/extracted/training_solutions_rev1.csv'
train_output = pd.read_csv(y_path,index_col='GalaxyID')
train_output.sort_index(inplace=True)

# %%
y_path_mod = '../01.data/extracted/training_solutions_rev1.csv'
train_output_mod = pd.read_csv(y_path_mod,index_col='GalaxyID')
train_output_mod.sort_index(inplace=True)

# %%
(train_output_mod.values!=train_output.values).sum()
# Out:
# 0

# %%
num_classes = 37
epochs = 1500


input_size = (32,32)
img_rows, img_cols = input_size
img_channels = 3
observations,output_classes = train_output.shape

# %%
from gc import collect

n = 1000#len(train_files)

train_x = np.zeros((n,img_rows,img_cols,img_channels),dtype=np.uint8)
train_y = np.zeros((n,num_classes),dtype=np.float32)

for current_id in tqdm(range(n),miniters=1000):
    
    if current_id%1000==0:
        collect()
        
    current_path = train_files[current_id]
    
    current_image  = np.array(get_image(current_path,input_size))
    current_labels = get_labels(current_path)
    
    train_x[current_id] = current_image
    train_y[current_id] = current_labels
    
    
train_y_expanded = np.expand_dims(np.expand_dims(train_y,1),1)
# Out:
# 100%|██████████| 1000/1000 [00:08<00:00, 116.00it/s]

# %%
print('train_x shape:', train_x.shape)
print('train_y shape:', train_y.shape)
print('train_y shape:', train_y_expanded.shape)
# Out:
# ('train_x shape:', (1000, 32, 32, 3))
# ('train_y shape:', (1000, 37))
# ('train_y shape:', (1000, 1, 1, 37))

# %%
from gc import collect

collect()
# Out:
# 0

# %%
from DenseNet import densenet_fast

# %%
K.clear_session()

model = densenet_fast.create_dense_net(
                          nb_classes=num_classes,
                          img_dim=(img_rows,img_cols,img_channels),
                          depth=64,
                          growth_rate=6)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# initial_conv2D (Conv2D)      (None, 32, 32, 16)        432
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 16)        64
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 6)         864
# _________________________________________________________________
# merge_1 (Merge)              (None, 32, 32, 22)        0
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 22)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 6)         1188
# _________________________________________________________________
# merge_2 (Merge)              (None, 32, 32, 28)        0
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 28)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 6)         1512
# _________________________________________________________________
# merge_3 (Merge)              (None, 32, 32, 34)        0
# _________________________________________________________________
# activation_4 (Activation)    (None, 32, 32, 34)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 6)         1836
# _________________________________________________________________
# merge_4 (Merge)              (None, 32, 32, 40)        0
# _________________________________________________________________
# activation_5 (Activation)    (None, 32, 32, 40)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 6)         2160
# _________________________________________________________________
# merge_5 (Merge)              (None, 32, 32, 46)        0
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 46)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 6)         2484
# _________________________________________________________________
# merge_6 (Merge)              (None, 32, 32, 52)        0
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 52)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 6)         2808
# _________________________________________________________________
# merge_7 (Merge)              (None, 32, 32, 58)        0
# _________________________________________________________________
# activation_8 (Activation)    (None, 32, 32, 58)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 6)         3132
# _________________________________________________________________
# merge_8 (Merge)              (None, 32, 32, 64)        0
# _________________________________________________________________
# activation_9 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 6)         3456
# _________________________________________________________________
# merge_9 (Merge)              (None, 32, 32, 70)        0
# _________________________________________________________________
# activation_10 (Activation)   (None, 32, 32, 70)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 6)         3780
# _________________________________________________________________
# merge_10 (Merge)             (None, 32, 32, 76)        0
# _________________________________________________________________
# activation_11 (Activation)   (None, 32, 32, 76)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 6)         4104
# _________________________________________________________________
# merge_11 (Merge)             (None, 32, 32, 82)        0
# _________________________________________________________________
# activation_12 (Activation)   (None, 32, 32, 82)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 6)         4428
# _________________________________________________________________
# merge_12 (Merge)             (None, 32, 32, 88)        0
# _________________________________________________________________
# activation_13 (Activation)   (None, 32, 32, 88)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 6)         4752
# _________________________________________________________________
# merge_13 (Merge)             (None, 32, 32, 94)        0
# _________________________________________________________________
# activation_14 (Activation)   (None, 32, 32, 94)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 6)         5076
# _________________________________________________________________
# merge_14 (Merge)             (None, 32, 32, 100)       0
# _________________________________________________________________
# activation_15 (Activation)   (None, 32, 32, 100)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 32, 32, 6)         5400
# _________________________________________________________________
# merge_15 (Merge)             (None, 32, 32, 106)       0
# _________________________________________________________________
# activation_16 (Activation)   (None, 32, 32, 106)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 32, 32, 6)         5724
# _________________________________________________________________
# merge_16 (Merge)             (None, 32, 32, 112)       0
# _________________________________________________________________
# activation_17 (Activation)   (None, 32, 32, 112)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 32, 6)         6048
# _________________________________________________________________
# merge_17 (Merge)             (None, 32, 32, 118)       0
# _________________________________________________________________
# activation_18 (Activation)   (None, 32, 32, 118)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 32, 32, 6)         6372
# _________________________________________________________________
# merge_18 (Merge)             (None, 32, 32, 124)       0
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 124)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 32, 32, 6)         6696
# _________________________________________________________________
# merge_19 (Merge)             (None, 32, 32, 130)       0
# _________________________________________________________________
# activation_20 (Activation)   (None, 32, 32, 130)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 6)         7020
# _________________________________________________________________
# merge_20 (Merge)             (None, 32, 32, 136)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 32, 32, 136)       18496
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 16, 16, 136)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 136)       544
# _________________________________________________________________
# activation_21 (Activation)   (None, 16, 16, 136)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 16, 16, 6)         7344
# _________________________________________________________________
# merge_21 (Merge)             (None, 16, 16, 142)       0
# _________________________________________________________________
# activation_22 (Activation)   (None, 16, 16, 142)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 16, 16, 6)         7668
# _________________________________________________________________
# merge_22 (Merge)             (None, 16, 16, 148)       0
# _________________________________________________________________
# activation_23 (Activation)   (None, 16, 16, 148)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 16, 6)         7992
# _________________________________________________________________
# merge_23 (Merge)             (None, 16, 16, 154)       0
# _________________________________________________________________
# activation_24 (Activation)   (None, 16, 16, 154)       0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 16, 16, 6)         8316
# _________________________________________________________________
# merge_24 (Merge)             (None, 16, 16, 160)       0
# _________________________________________________________________
# activation_25 (Activation)   (None, 16, 16, 160)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 16, 16, 6)         8640
# _________________________________________________________________
# merge_25 (Merge)             (None, 16, 16, 166)       0
# _________________________________________________________________
# activation_26 (Activation)   (None, 16, 16, 166)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 16, 16, 6)         8964
# _________________________________________________________________
# merge_26 (Merge)             (None, 16, 16, 172)       0
# _________________________________________________________________
# activation_27 (Activation)   (None, 16, 16, 172)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 16, 16, 6)         9288
# _________________________________________________________________
# merge_27 (Merge)             (None, 16, 16, 178)       0
# _________________________________________________________________
# activation_28 (Activation)   (None, 16, 16, 178)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 16, 16, 6)         9612
# _________________________________________________________________
# merge_28 (Merge)             (None, 16, 16, 184)       0
# _________________________________________________________________
# activation_29 (Activation)   (None, 16, 16, 184)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 16, 16, 6)         9936
# _________________________________________________________________
# merge_29 (Merge)             (None, 16, 16, 190)       0
# _________________________________________________________________
# activation_30 (Activation)   (None, 16, 16, 190)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 16, 16, 6)         10260
# _________________________________________________________________
# merge_30 (Merge)             (None, 16, 16, 196)       0
# _________________________________________________________________
# activation_31 (Activation)   (None, 16, 16, 196)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 16, 16, 6)         10584
# _________________________________________________________________
# merge_31 (Merge)             (None, 16, 16, 202)       0
# _________________________________________________________________
# activation_32 (Activation)   (None, 16, 16, 202)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 16, 16, 6)         10908
# _________________________________________________________________
# merge_32 (Merge)             (None, 16, 16, 208)       0
# _________________________________________________________________
# activation_33 (Activation)   (None, 16, 16, 208)       0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 16, 16, 6)         11232
# _________________________________________________________________
# merge_33 (Merge)             (None, 16, 16, 214)       0
# _________________________________________________________________
# activation_34 (Activation)   (None, 16, 16, 214)       0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 16, 16, 6)         11556
# _________________________________________________________________
# merge_34 (Merge)             (None, 16, 16, 220)       0
# _________________________________________________________________
# activation_35 (Activation)   (None, 16, 16, 220)       0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 16, 16, 6)         11880
# _________________________________________________________________
# merge_35 (Merge)             (None, 16, 16, 226)       0
# _________________________________________________________________
# activation_36 (Activation)   (None, 16, 16, 226)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 16, 16, 6)         12204
# _________________________________________________________________
# merge_36 (Merge)             (None, 16, 16, 232)       0
# _________________________________________________________________
# activation_37 (Activation)   (None, 16, 16, 232)       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 16, 16, 6)         12528
# _________________________________________________________________
# merge_37 (Merge)             (None, 16, 16, 238)       0
# _________________________________________________________________
# activation_38 (Activation)   (None, 16, 16, 238)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 16, 16, 6)         12852
# _________________________________________________________________
# merge_38 (Merge)             (None, 16, 16, 244)       0
# _________________________________________________________________
# activation_39 (Activation)   (None, 16, 16, 244)       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 16, 16, 6)         13176
# _________________________________________________________________
# merge_39 (Merge)             (None, 16, 16, 250)       0
# _________________________________________________________________
# activation_40 (Activation)   (None, 16, 16, 250)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 16, 16, 6)         13500
# _________________________________________________________________
# merge_40 (Merge)             (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 16, 16, 256)       65536
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_41 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 8, 8, 6)           13824
# _________________________________________________________________
# merge_41 (Merge)             (None, 8, 8, 262)         0
# _________________________________________________________________
# activation_42 (Activation)   (None, 8, 8, 262)         0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 8, 8, 6)           14148
# _________________________________________________________________
# merge_42 (Merge)             (None, 8, 8, 268)         0
# _________________________________________________________________
# activation_43 (Activation)   (None, 8, 8, 268)         0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 8, 8, 6)           14472
# _________________________________________________________________
# merge_43 (Merge)             (None, 8, 8, 274)         0
# _________________________________________________________________
# activation_44 (Activation)   (None, 8, 8, 274)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 8, 8, 6)           14796
# _________________________________________________________________
# merge_44 (Merge)             (None, 8, 8, 280)         0
# _________________________________________________________________
# activation_45 (Activation)   (None, 8, 8, 280)         0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 8, 8, 6)           15120
# _________________________________________________________________
# merge_45 (Merge)             (None, 8, 8, 286)         0
# _________________________________________________________________
# activation_46 (Activation)   (None, 8, 8, 286)         0
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 8, 8, 6)           15444
# _________________________________________________________________
# merge_46 (Merge)             (None, 8, 8, 292)         0
# _________________________________________________________________
# activation_47 (Activation)   (None, 8, 8, 292)         0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 8, 8, 6)           15768
# _________________________________________________________________
# merge_47 (Merge)             (None, 8, 8, 298)         0
# _________________________________________________________________
# activation_48 (Activation)   (None, 8, 8, 298)         0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 8, 8, 6)           16092
# _________________________________________________________________
# merge_48 (Merge)             (None, 8, 8, 304)         0
# _________________________________________________________________
# activation_49 (Activation)   (None, 8, 8, 304)         0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 8, 8, 6)           16416
# _________________________________________________________________
# merge_49 (Merge)             (None, 8, 8, 310)         0
# _________________________________________________________________
# activation_50 (Activation)   (None, 8, 8, 310)         0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 8, 8, 6)           16740
# _________________________________________________________________
# merge_50 (Merge)             (None, 8, 8, 316)         0
# _________________________________________________________________
# activation_51 (Activation)   (None, 8, 8, 316)         0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 8, 8, 6)           17064
# _________________________________________________________________
# merge_51 (Merge)             (None, 8, 8, 322)         0
# _________________________________________________________________
# activation_52 (Activation)   (None, 8, 8, 322)         0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 8, 8, 6)           17388
# _________________________________________________________________
# merge_52 (Merge)             (None, 8, 8, 328)         0
# _________________________________________________________________
# activation_53 (Activation)   (None, 8, 8, 328)         0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 8, 8, 6)           17712
# _________________________________________________________________
# merge_53 (Merge)             (None, 8, 8, 334)         0
# _________________________________________________________________
# activation_54 (Activation)   (None, 8, 8, 334)         0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 8, 8, 6)           18036
# _________________________________________________________________
# merge_54 (Merge)             (None, 8, 8, 340)         0
# _________________________________________________________________
# activation_55 (Activation)   (None, 8, 8, 340)         0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 8, 8, 6)           18360
# _________________________________________________________________
# merge_55 (Merge)             (None, 8, 8, 346)         0
# _________________________________________________________________
# activation_56 (Activation)   (None, 8, 8, 346)         0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 8, 8, 6)           18684
# _________________________________________________________________
# merge_56 (Merge)             (None, 8, 8, 352)         0
# _________________________________________________________________
# activation_57 (Activation)   (None, 8, 8, 352)         0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 8, 8, 6)           19008
# _________________________________________________________________
# merge_57 (Merge)             (None, 8, 8, 358)         0
# _________________________________________________________________
# activation_58 (Activation)   (None, 8, 8, 358)         0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 8, 8, 6)           19332
# _________________________________________________________________
# merge_58 (Merge)             (None, 8, 8, 364)         0
# _________________________________________________________________
# activation_59 (Activation)   (None, 8, 8, 364)         0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 8, 8, 6)           19656
# _________________________________________________________________
# merge_59 (Merge)             (None, 8, 8, 370)         0
# _________________________________________________________________
# activation_60 (Activation)   (None, 8, 8, 370)         0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 8, 8, 6)           19980
# _________________________________________________________________
# merge_60 (Merge)             (None, 8, 8, 376)         0
# _________________________________________________________________
# activation_61 (Activation)   (None, 8, 8, 376)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 376)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               75400
# _________________________________________________________________
# activation_62 (Activation)   (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 37)                7437
# =================================================================
# Total params: 794,253
# Trainable params: 793,437
# Non-trainable params: 816
# _________________________________________________________________

# %%
from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from keras.callbacks import EarlyStopping, LearningRateScheduler
from keras_tqdm import TQDMNotebookCallback

tb = TensorBoard(
        log_dir='../tensorboard/'+run+'/',
        write_graph=True,
        write_images=True,
        embeddings_freq=1
    )

mc = ModelCheckpoint(filepath = '../05.model/'+run+'.h5',
                     save_best_only = True)

ec = EarlyStopping(monitor='val_loss',
                   patience=20,
                   mode='auto')

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.5,
                              patience=3,
                              min_lr=1e-15)

tqnc = TQDMNotebookCallback()

# %%
batch_size = 250

train_steps = 5*train_x.shape[0]/batch_size
validation_steps = 0.1 * train_steps

# %%
def custom_preprocessing(image_input):
    
    image_input = image_input * 1.0/255
    
    return(image_output)

def custom_generator(train_files, labels, batch_size):
    
    # Create empty arrays to contain batch of features and labels#
    batch_features = np.zeros((batch_size, img_rows,img_cols,img_channels))
    batch_labels = np.zeros((batch_size,num_classes))

    while True:
        for i in range(batch_size):
            
            # choose random index in features
            index= random.choice(len(train_files),1)
            image_path = train_files[index]
            image_input = cv2.imread(image_path)
            
            batch_features[i] = custom_preprocessing(image_input)
            
        yield batch_features, batch_labels

# %%
from keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(
                                rotation_range=180,
                                vertical_flip=True,
                                horizontal_flip=True,
                                width_shift_range=0.25, 
                                height_shift_range=0.25,
                                data_format='channels_last',
                                
)

validation_datagen = ImageDataGenerator(
                                data_format='channels_last',
)

# %% [markdown]
# train_generator = train_datagen.flow(
#                                     x=train_x,
#                                     y=train_y,
#                                     batch_size=batch_size
# )
#
# validation_generator = validation_datagen.flow(
#                                             x=train_x,
#                                             y=train_y,
#                                             batch_size=batch_size
# )

# %%
with tf.device(device_use):

    model.compile(loss='mse',
                  optimizer=keras.optimizers.adam(lr=1e-3)
                 )
    
    loss_history = model.fit_generator(
                                    generator=train_datagen.flow(
                                                                x=train_x,
                                                                y=train_y,
                                                                batch_size=batch_size
                                                                ),
                                    validation_data=validation_datagen.flow(
                                                                            x=train_x,
                                                                            y=train_y,
                                                                            batch_size=batch_size
                                                                            ),
                                    steps_per_epoch=train_steps,
                                    validation_steps=validation_steps,
                                    callbacks=[tb,mc,ec,reduce_lr,tqnc],
                                    epochs=epochs,
                                    max_q_size=2,
                                    verbose=1
                )


loss_df = pd.DataFrame(loss_history.history)
loss_df.to_csv('../03.plots/losses/augmented_loss_df'+run+'.csv',
                   index=False)
# Out:
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Widget Javascript not detected.  It may not be installed properly. Did you enable the widgetsnbextension? If not, then run "jupyter nbextension enable --py --sys-prefix widgetsnbextension"
# Epoch 1/1500
#  1/20 [>.............................] - ETA: 316s - loss: 0.2652
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-24-d7d166c4fb4e> in <module>()
#      21                                     epochs=epochs,
#      22                                     max_q_size=2,
# ---> 23                                     verbose=1
#      24                 )
#      25
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/keras/legacy/interfaces.pyc in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1875                     outs = self.train_on_batch(x, y,
#    1876                                                sample_weight=sample_weight,
# -> 1877                                                class_weight=class_weight)
#    1878
#    1879                     if not isinstance(outs, list):
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1619             ins = x + y + sample_weights
#    1620         self._make_train_function()
# -> 1621         outputs = self.train_function(ins)
#    1622         if len(outputs) == 1:
#    1623             return outputs[0]
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2101         session = get_session()
#    2102         updated = session.run(self.outputs + [self.updates_op],
# -> 2103                               feed_dict=feed_dict)
#    2104         return updated[:len(self.outputs)]
#    2105
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /software/intel/2017/intelpython27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# with tf.device(device_use):
#
#     model.compile(loss='mse',
#                   optimizer=keras.optimizers.adam(lr=1e-4)
#                  )
#
#     loss_history = model.fit(x=train_x-30,
#                              y=train_y,
#                              batch_size=5,
#                              validation_split=0.1,
#                              callbacks=[tb,mc,ec,reduce_lr,tqnc],
#                              epochs=epochs,
#                              verbose=1
#                             )
#
#
# loss_df = pd.DataFrame(loss_history.history)
# loss_df.to_csv('../03.plots/losses/augmented_loss_df'+run+'.csv',
#                    index=False)

# %% [markdown]
# $$ \frac{1}{N} \sum_{i=0}^{N} Actual_{i} = Predicted_{i} $$

# %%
data_plot = loss_df.ix[1:,:]
sns.set(style='whitegrid',)
sns.plt.figure(figsize=(7.5,3.5))

plt.plot(data_plot.index,data_plot.loss,label='train')
plt.plot(data_plot.index,data_plot.val_loss,label='validation')
plt.legend()
plt.title('Train & Validation loss');

# %% [markdown]
# #### Test data

# %%
out = {}

with tf.device(device_use):  
    for file_path in tqdm(test_files):
        galaxy_id = file_path.split('/')[-1].split('.')[0]
        galaxy_img = np.expand_dims(cv2.resize(cv2.imread(file_path),
                                               input_size),
                                    axis=0)
        galaxy_pred = model.predict(galaxy_img).flatten()

        out[galaxy_id] = galaxy_pred

# %%
columns = pd.read_csv(y_path,
                      index_col='GalaxyID',
                      nrows=0)

test_results = pd.DataFrame.from_dict(data = out,
                                      orient='index')
test_results.index.name = 'GalaxyID'
test_results.columns = columns.columns

# %%
test_results.to_csv('../04.results/submission'+run+'.csv',
                    index_label='GalaxyID')
